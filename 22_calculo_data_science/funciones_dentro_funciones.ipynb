# %%
import numpy as np 
import matplotlib.pyplot as plt 

def g(x):
    return x**3

def f(x):
    return x**0.5

x = np.linspace(-10,10, num=100)

f_o_g = f(g(x))
plt.plot(x, f_o_g)
plt.grid()
# Out:
# <ipython-input-6-8e604e000215>:8: RuntimeWarning: invalid value encountered in sqrt
#   return x**0.5
